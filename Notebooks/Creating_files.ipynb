# %%
import numpy as np
import pandas as pd

data = {
    'id' : [1,2,3],
    'name' : ['Alice', 'Bob', 'Charlie'],
    'age' : [25,30,35], 
    'city' : ['New York', 'London', 'Paris']
}
df = pd.DataFrame(data)

filepath = ("C:/Users/bathr/Downloads/dataaaaaaaa.csv")
df.to_csv(filepath, index = False)

# %%
d = pd.read_csv("C:/Users/bathr/Downloads/dataaaaaaaa.csv")
print(type(d))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = {
    'id' : [1,2,3],
    'name' : ['Alice', 'Bob', 'Charlie'],
    'age' : [25,30,35], 
    'city' : ['New York', 'London', 'Paris']
}

df = pd.DataFrame(data)

filepath = ("C:/Users/bathr/Downloads/dataaaaaaaa.json")

df.to_json(filepath)

# %%
d = pd.read_csv("C:/Users/bathr/Downloads/dataaaaaaaa.json")
print(type(d))
# Out:
# <class 'pandas.core.frame.DataFrame'>
