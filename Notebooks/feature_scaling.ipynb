# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
df = pd.DataFrame({
    'age' : [18, 22, 30, 45, 60, 80],
    'salary':[20000,25000, 40000, 60000, 120000,1000000]
    })
print('Org data')
display(df)
# Out:
# Org data
#    age   salary
# 0   18    20000
# 1   22    25000
# 2   30    40000
# 3   45    60000
# 4   60   120000
# 5   80  1000000

# %% [markdown]
# ## MinMaxScaler

# %%
minmax_scaler = MinMaxScaler()
df_minmax = pd.DataFrame(minmax_scaler.fit_transform(df), columns = df.columns)

print('\n Min Max Scaled Data\n',df_minmax)
# Out:
#  Min Max Scaled Data
#          age    salary
# 0  0.000000  0.000000
# 1  0.064516  0.005102
# 2  0.193548  0.020408
# 3  0.435484  0.040816
# 4  0.677419  0.102041
# 5  1.000000  1.000000

# %% [markdown]
# #### FORMULA FOR MIN MAX SCALER = (X- Xmin) / (Xmax - Xmin)

# %% [markdown]
# # Standard Scaler

# %%
standard_scaler = StandardScaler()
df_standard = pd.DataFrame(standard_scaler.fit_transform(df), columns = df.columns)
print("\n Standard Scaled Data")
print(df_standard)
# Out:
#  Standard Scaled Data
#         age    salary
# 0 -1.115270 -0.538353
# 1 -0.933185 -0.524248
# 2 -0.569015 -0.481932
# 3  0.113803 -0.425510
# 4  0.796621 -0.256247
# 5  1.707046  2.226289

# %% [markdown]
# ### Standard Scaler Fromula : z = (X - µ)/ sigma

# %% [markdown]
# ## Robust Scaler

# %%
robust_scaler = RobustScaler()
df_robust = pd.DataFrame(robust_scaler.fit_transform(df), columns= df.columns)
print("\n Robust Scaled Data")
print(df_robust)
# Out:
#  Robust Scaled Data
#         age     salary
# 0 -0.604651  -0.393443
# 1 -0.480620  -0.327869
# 2 -0.232558  -0.131148
# 3  0.232558   0.131148
# 4  0.697674   0.918033
# 5  1.317829  12.459016

# %% [markdown]
# #### This removes outliers first and then uses either minmax or standard scaler
